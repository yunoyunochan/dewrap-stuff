# %%
# hf auth login
# https://huggingface.co/datasets/StonyBrook-CVLab/doc3D-dataset

import shutil
from pathlib import Path

# ลบ cache
cache_paths = [
    Path.home() / ".cache/huggingface/datasets/StonyBrook-CVLab___doc3d-dataset",
    Path.home() / ".cache/huggingface/downloads"
]

for path in cache_paths:
    if path.exists():
        shutil.rmtree(path)
        print(f"Deleted: {path}")

# # โหลดใหม่
# from datasets import load_dataset
# dataset = load_dataset("StonyBrook-CVLab/doc3D-dataset")
# print(dataset)
# Out:
# Resolving data files:   0%|          | 0/156 [00:00<?, ?it/s]
# data.gif:   0%|          | 0.00/6.00M [00:00<?, ?B/s]
# ...
# doc3d/alb_1.zip:   0%|          | 0.00/289M [00:00<?, ?B/s]
# doc3d/alb_2.zip:   0%|          | 0.00/290M [00:00<?, ?B/s]
# doc3d/alb_3.zip:   0%|          | 0.00/321M [00:00<?, ?B/s]
# doc3d/alb_4.zip:   0%|          | 0.00/340M [00:00<?, ?B/s]
# doc3d/alb_5.zip:   0%|          | 0.00/285M [00:00<?, ?B/s]
# doc3d/alb_6.zip:   0%|          | 0.00/306M [00:00<?, ?B/s]
# doc3d/alb_7.zip:   0%|          | 0.00/343M [00:00<?, ?B/s]
# doc3d/alb_8.zip:   0%|          | 0.00/192M [00:00<?, ?B/s]
# doc3d/bm_1.zip:   0%|          | 0.00/14.2G [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# doc3d/bm_10.zip:   0%|          | 0.00/14.1G [00:00<?, ?B/s]
